# %%
from sane import SANEAlgorithm
from sane import Mushroom1Dataset
import random
import matplotlib.pyplot as plt

# %%
random.seed(1)

# %%
algorithm_params = [
        (50, 1000, 5, 4),
        (50, 1000, 5, 8),
        (50, 1000, 25, 4),
        (50, 1000, 25, 8)
]

# %%
algorithms = []
for params in algorithm_params:
        algorithms.append(SANEAlgorithm(
                blueprints_population_size=params[0],
                neuron_population_size=params[1],
                hidden_layer_size=params[2],
                connections_count=params[3]))
for i in range(len(algorithms)):
        algorithms[i].init(min_value=-1.0, max_value=1.0)

# %%
mushroom1_dataset = Mushroom1Dataset()
x_train, y_train = mushroom1_dataset.get_train_data()

# %%
results = []
for i in range(len(algorithms)):
        result = algorithms[i].train(
            generations_count=20, x_train=x_train, y_train=y_train)
        results.append(result)
# Out:
# 19/20 best fitness = 0.2350389961003078, current fitness = 0.337963752762271456

# %%
legend = []
for i in range(len(results)):
       plt.plot(results[i])
       legend.append("Params " + str(i+1))
plt.legend(legend)
plt.show()

# %%
x_test, y_test = mushroom1_dataset.get_test_data()

# %%
results = []
for i in range(len(algorithms)):
        result = algorithms[i].test(
            x_test=x_test, y_test=y_test)
        results.append(result)

# %%
legend = []
for i in range(len(results)):
       plt.plot(results[i])
       legend.append("Params " + str(i+1))
plt.legend(legend)
plt.show()
